# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sn

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("database_IND.csv")

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df.head(10)
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
# 5     IND        India              AKRIMOTA LIG  IND0000003        250.0
# 6     IND        India                    ALIYAR  IND0000004         60.0
# 7     IND        India           ALLAIN DUHANGAN  IND0000005        192.0
# 8     IND        India               ALMATTI DAM  IND0000006        290.0
# 9     IND        India               AMAR KANTAK  IND0000007        210.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# ...

# %%
df.tail(10)
# Out:
#     country country_long                                               name  \
# 897     IND        India  Wind power project by Riddhi Siddhi Gluco Biol...
# 898     IND        India                    Wind power project in Rajasthan
# 899     IND        India                                    YAMUNANAGAR TPP
# 900     IND        India                                 YASHWANTRAO MOHITE
# 901     IND        India                                      YELHANKA (DG)
# 902     IND        India                                       YERMARUS TPP
# 903     IND        India                       Yelesandra Solar Power Plant
# 904     IND        India                       Yelisirur wind power project
# 905     IND        India                                        ZAWAR MINES
# 906     IND        India                            iEnergy Theni Wind Farm
#
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %% [markdown]
# There are 12 object and 13 numerical columns in data
# We are going to remove some columns those having maximum no of null values because if we fill those values prediction will not correct

# %%
df.shape
# Out:
# (907, 27)

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# ...

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# NaN are present in the dataset in a large amount

# %%
sn.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Heat map showing that there are many  null values

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
df.drop(['other_fuel1','other_fuel2', 'other_fuel3', 'wepp_id','url','geolocation_source', 'generation_data_source', 'estimated_generation_gwh','source','year_of_capacity_data','country', 'country_long','owner','gppd_idnr'], inplace= True, axis= 1)

# %%
df
# Out:
#                              name  capacity_mw  latitude  longitude  \
# 0                ACME Solar Tower          2.5   28.1839    73.2407
# 1             ADITYA CEMENT WORKS         98.0   24.7663    74.6090
# 2        AES Saurashtra Windfarms         39.2   21.9038    69.3732
# 3                     AGARTALA GT        135.0   23.8712    91.3602
# 4                    AKALTARA TPP       1800.0   21.9603    82.4091
# ..                            ...          ...       ...        ...
# 902                  YERMARUS TPP       1600.0   16.2949    77.3568
# 903  Yelesandra Solar Power Plant          3.0   12.8932    78.1654
# 904  Yelisirur wind power project         25.5   15.2758    75.5811
# 905                   ZAWAR MINES         80.0   24.3500    73.7477
# 906       iEnergy Theni Wind Farm         16.5    9.9344    77.4768
#
#     primary_fuel  commissioning_year  generation_gwh_2013  \
# 0          Solar              2011.0                  NaN
# ...

# %% [markdown]
# Dropping the unwanted Column

# %%
df.isnull().sum()
# Out:
# name                     0
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# commissioning_year     380
# generation_gwh_2013    907
# generation_gwh_2014    509
# generation_gwh_2015    485
# generation_gwh_2016    473
# generation_gwh_2017    467
# generation_gwh_2018    459
# generation_gwh_2019    907
# dtype: int64

# %%
df['generation_gwh_2013'].fillna(value=df['generation_gwh_2013'].median(), inplace= True)
df['generation_gwh_2014'].fillna(value=df['generation_gwh_2014'].median(), inplace= True)
df['generation_gwh_2015'].fillna(value=df['generation_gwh_2015'].median(), inplace= True)
df['generation_gwh_2016'].fillna(value=df['generation_gwh_2016'].median(), inplace= True)
df['generation_gwh_2017'].fillna(value=df['generation_gwh_2017'].median(), inplace= True)
df['generation_gwh_2018'].fillna(value=df['generation_gwh_2018'].median(), inplace= True)
df['generation_gwh_2019'].fillna(value=df['generation_gwh_2019'].median(), inplace= True)
df['commissioning_year'].fillna(value=df['commissioning_year'].median(), inplace= True)

# %% [markdown]
# Filling the catagorical column by median

# %%
df['latitude'].fillna(value=df['latitude'].mean(), inplace= True)
df['longitude'].fillna(value=df['longitude'].mean(), inplace= True) 
df['generation_gwh_2013'].fillna(value=df['generation_gwh_2013'].mode(), inplace= True)

# %% [markdown]
# Filling the numerical columns by mean

# %%
df.isnull().sum()
# Out:
# name                     0
# capacity_mw              0
# latitude                 0
# longitude                0
# primary_fuel             0
# commissioning_year       0
# generation_gwh_2013    907
# generation_gwh_2014      0
# generation_gwh_2015      0
# generation_gwh_2016      0
# generation_gwh_2017      0
# generation_gwh_2018      0
# generation_gwh_2019    907
# dtype: int64

# %%
df.drop(['generation_gwh_2013','generation_gwh_2019'], inplace= True, axis= 1)

# %% [markdown]
# Dropping the two columns having only NaN

# %%
df.isnull().sum()
# Out:
# name                   0
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# commissioning_year     0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# generation_gwh_2018    0
# dtype: int64

# %%
sn.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking for the null values and thus have no null values

# %%
df.nunique()
# Out:
# name                   907
# capacity_mw            361
# latitude               837
# longitude              828
# primary_fuel             8
# commissioning_year      73
# generation_gwh_2014    372
# generation_gwh_2015    397
# generation_gwh_2016    404
# generation_gwh_2017    409
# generation_gwh_2018    411
# dtype: int64

# %%
categorical=[]
integer=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical.append(i)
    if df.dtypes[i]!="object":
        integer.append(i)
print(categorical)
print(integer)
# Out:
# ['name', 'primary_fuel']
# ['capacity_mw', 'latitude', 'longitude', 'commissioning_year', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018']

# %% [markdown]
# Catagorical and Numerical Columns seperation

# %% [markdown]
# # Visualization

# %%
sn.set_style("whitegrid")
sn.countplot(x="primary_fuel", data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='count'>

# %% [markdown]
# Primary fuel distribution

# %%
sn.catplot(x = "primary_fuel", y = "longitude", data = df)
plt.show()

# %%
plt.style.use('seaborn-pastel')
sn.catplot(x = "primary_fuel", y = "capacity_mw", data = df)
plt.show()

# %%
print(df['capacity_mw'].value_counts())   #visualizing the capacity_mw
plt.figure(figsize=(10,10))
sn.countplot(df['capacity_mw'])
plt.show()
# Out:
# 5.0       39
# 10.0      22
# 15.0      20
# 600.0     20
# 1200.0    19
#           ..
# 192.0      1
# 27.3       1
# 26.4       1
# 68.8       1
# 19.7       1
# Name: capacity_mw, Length: 361, dtype: int64

# %%
sn.displot(df["longitude"])

# %%
sn.displot(df["commissioning_year"])

# %%
plt.figure(figsize=(15,7))
values = list(df['commissioning_year'].unique())
diag = sn.countplot(df["commissioning_year"], palette="prism")
diag.set_xticklabels(labels=values, rotation=90)
plt.title("Power plant operation details\n")
plt.xlabel("List of years by unit-capacity for available data")
plt.ylabel("Number of Rows in the Dataset")
plt.show()

# %%
sn.displot(df["latitude"])

# %%
plt.style.use('ggplot')
sn.scatterplot(x = "commissioning_year", y = "capacity_mw", data = df)
plt.show()

# %%
sn.scatterplot(x = "longitude", y = "capacity_mw", data = df)
plt.show()

# %%
plt.figure(figsize=(8,4))
sn.scatterplot(x='capacity_mw',y='latitude',data=df)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='latitude'>

# %%
sn.set_theme(style="darkgrid")
plt.figure(figsize=(10,6))

sn.distplot(df['capacity_mw'], color='red',kde_kws={"color": "k", "lw": 1.5, "label": "KDE"})
plt.title('capacity_mw', fontsize=12)
plt.xlabel('Capacity_mw', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))

sn.distplot(df['generation_gwh_2014'], color='red',kde_kws={"color": "k", "lw": 1.5, "label": "KDE"})
plt.title('generation_gwh_2014', fontsize=12)
plt.xlabel('Generation giga byte', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))

sn.distplot(df['generation_gwh_2015'], color='red',kde_kws={"color": "k", "lw": 1.5, "label": "KDE"})
plt.title('generation_gwh_2015', fontsize=12)
plt.xlabel('Generation giga byte', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))

sn.distplot(df['generation_gwh_2016'], color='red',kde_kws={"color": "k", "lw": 1.5, "label": "KDE"})
plt.title('generation_gwh_2016', fontsize=12)
plt.xlabel('Generation giga byte', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(16,8))
sn.lineplot(data=df, x='primary_fuel',y='generation_gwh_2016')
locs, labels = plt.xticks()
plt.title('generation_gwh_2016 vs capacity_mw ', fontsize=10)
plt.setp(labels, rotation=60)
plt.show()

# %%
plt.figure(figsize=(10,6))

sn.distplot(df['generation_gwh_2017'], color='red',kde_kws={"color": "k", "lw": 1.5, "label": "KDE"})
plt.title('generation_gwh_2017', fontsize=12)
plt.xlabel('Generation giga byte', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))

sn.distplot(df['generation_gwh_2018'], color='red',kde_kws={"color": "k", "lw": 1.5, "label": "KDE"})
plt.title('generation_gwh_2018', fontsize=12)
plt.xlabel('Generation giga byte', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sn.scatterplot(x='capacity_mw',y='primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='primary_fuel'>

# %%
plt.figure(figsize=(10,6))
sn.scatterplot(x='primary_fuel',y='latitude',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='latitude'>

# %%
plt.figure(figsize=(16,8))
sn.scatterplot(data=df, x='primary_fuel',y='capacity_mw')
locs, labels = plt.xticks()
plt.title('primary_fuel vs capacity_mw ', fontsize=10)
plt.setp(labels, rotation=60)
plt.show()

# %%
df.hist(figsize = (30,20), grid = False)
# Out:
# array([[<AxesSubplot:title={'center':'capacity_mw'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'longitude'}>],
#        [<AxesSubplot:title={'center':'commissioning_year'}>,
#         <AxesSubplot:title={'center':'generation_gwh_2014'}>,
#         <AxesSubplot:title={'center':'generation_gwh_2015'}>],
#        [<AxesSubplot:title={'center':'generation_gwh_2016'}>,
#         <AxesSubplot:title={'center':'generation_gwh_2017'}>,
#         <AxesSubplot:title={'center':'generation_gwh_2018'}>]],
#       dtype=object)

# %%
sn.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 907 non-null    object
#  1   capacity_mw          907 non-null    float64
#  2   latitude             907 non-null    float64
#  3   longitude            907 non-null    float64
#  4   primary_fuel         907 non-null    object
#  5   commissioning_year   907 non-null    float64
#  6   generation_gwh_2014  907 non-null    float64
#  7   generation_gwh_2015  907 non-null    float64
#  8   generation_gwh_2016  907 non-null    float64
#  9   generation_gwh_2017  907 non-null    float64
#  10  generation_gwh_2018  907 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 78.1+ KB

# %% [markdown]
# Here we have 2 object type which we have to change in numeric.

# %% [markdown]
# # Checking Outliers

# %%
df['capacity_mw'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['latitude'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['longitude'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['primary_fuel'].plot.box()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-bd9b921bbd94> in <module>
# ----> 1 df['primary_fuel'].plot.box()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in box(self, by, **kwargs)
#    1247             >>> ax = df.plot.box()
#    1248         """
# -> 1249         return self(kind="box", by=by, **kwargs)
#    1250
#    1251     def hist(self, by=None, bins=10, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
# ...

# %% [markdown]
# Ran the proramme again and because i have encoded the column so can not find any outliers

# %%
df['generation_gwh_2014'].plot.box()

# %%
df['generation_gwh_2015'].plot.box()

# %%
df['generation_gwh_2016'].plot.box()

# %%
df['generation_gwh_2017'].plot.box()

# %%
df['generation_gwh_2018'].plot.box()

# %%
# Checking presence of outlier in the dataset using boxplot
plt.figure(figsize=(25,20))
plot=1
for column in integer:
    if plot<=13:
        plt.figure(figsize=(10,10))
        ax=plt.subplot(7,2,plot)
        sn.boxplot(df[column])
        plt.xlabel(column, fontsize=18)
    plot+=1
plt.tight_layout

# %% [markdown]
# We have many outliers present in the Dataset

# %% [markdown]
# # Removing Outliers

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder

encoder = LabelEncoder()
df['primary_fuel'] = encoder.fit_transform(df['primary_fuel'])
df['name'] = encoder.fit_transform(df['name'])

# %% [markdown]
# Encoding the object type columns so that we can use Z square method

# %%
df.info()

# %% [markdown]
# Applying the Z-square method

# %%
from scipy.stats import zscore

z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy()

# %% [markdown]
# We can get more than 90% data which is OK

# %% [markdown]
# # Correlatoion

# %%
# dividing the dataset into dependent and independent variables

df.corr()

# %%
# visualizing the correlation matrix by plotting heat map

plt.figure(figsize=(15,10))
sn.heatmap(df.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.2g', annot = True, linecolor='black',annot_kws={'size':15},cmap="YlGnBu")
plt.yticks(rotation=0);

# %% [markdown]
# # Train and Test Split

# %%
x= df.drop('capacity_mw',axis=1)
y= df['capacity_mw']

# %%
x.shape
# Out:
# (692, 10)

# %%
y.shape
# Out:
# (692,)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#          name  latitude  longitude  primary_fuel  commissioning_year  \
# 0   -1.713716  1.147240  -0.828142      0.990900            1.310346
# 1   -1.709142  0.585848  -0.475116     -1.102210            0.090271
# 2   -1.704568  0.115639  -1.825970      1.409523            0.090271
# 3   -1.699995  0.422010  -2.013925     -1.102210            0.578301
# 4   -1.690847  1.811184   0.195177     -0.264966            1.188339
# ..        ...       ...        ...           ...                 ...
# 687  1.716571 -1.327957   0.292392      0.572278           -0.885788
# 688  1.721145 -1.364489   0.442447      0.990900            0.090271
# 689  1.725718 -0.973111  -0.224311      1.409523            0.090271
# 690  1.730292  0.517464  -0.697334     -1.102210            0.090271
# 691  1.734866 -1.850517   0.264786      1.409523            0.090271
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0              -0.013714            -0.011644             0.025831
# ...

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    mod = RandomForestRegressor()
    mod.fit(x_train,y_train)
    pred = mod.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.7813620597315889  on Random_state  129

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score

# %%
# checking r2 score for random forest regressor
RFR = RandomForestRegressor()
RFR.fit(x_train,y_train)

# prediction
predRFR=RFR.predict(x_test)
print('R2_Score:',r2_score(y_test,predRFR))
print('MAE:',metrics.mean_absolute_error(y_test,predRFR))
print('MSE:',metrics.mean_squared_error(y_test,predRFR))
print('RNSE:',np.sqrt(metrics.mean_squared_error(y_test,predRFR)))
# Out:
# R2_Score: 0.7896339569939131
# MAE: 53.30449624999999
# MSE: 7462.0798577203095
# RNSE: 86.38333090197617

# %%
# checking r2 score for decision tree regressor
DTR = DecisionTreeRegressor()
DTR.fit(x_train,y_train)

# prediction
predDTR=DTR.predict(x_test)
print('R2_Score:',r2_score(y_test,predDTR))
print('MAE:',metrics.mean_absolute_error(y_test,predDTR))
print('MSE:',metrics.mean_squared_error(y_test,predDTR))
print('RNSE:',np.sqrt(metrics.mean_squared_error(y_test,predDTR)))
# Out:
# R2_Score: 0.46946747071459016
# MAE: 69.46191826923076
# MSE: 18818.98829333173
# RNSE: 137.18231771380644

# %%
# checking r2 score for Kneighbors regressor
knn = KNN()
knn.fit(x_train,y_train)

# prediction
predknn=knn.predict(x_test)
print('R2_Score:',r2_score(y_test,predknn))
print('MAE:',metrics.mean_absolute_error(y_test,predknn))
print('MSE:',metrics.mean_squared_error(y_test,predknn))
print('RNSE:',np.sqrt(metrics.mean_squared_error(y_test,predknn)))
# Out:
# R2_Score: 0.6699130198254193
# MAE: 64.90731634615385
# MSE: 11708.807043469425
# RNSE: 108.207241178534

# %%
# checking r2 score for gradient boosting regressor
GB = GradientBoostingRegressor()
GB.fit(x_train,y_train)

# prediction
predGB=GB.predict(x_test)
print('R2_Score:',r2_score(y_test,predGB))
print('MAE:',metrics.mean_absolute_error(y_test,predGB))
print('MSE:',metrics.mean_squared_error(y_test,predGB))
print('RNSE:',np.sqrt(metrics.mean_squared_error(y_test,predGB)))
# Out:
# R2_Score: 0.7953002759087628
# MAE: 51.6586057300167
# MSE: 7261.084850932563
# RNSE: 85.21199945390651

# %% [markdown]
# # Cross Validatiopn

# %%
# checking cv score for Random Forest Regressor
print(cross_val_score(RFR,x,y,cv=5).mean())
# Out:
# 0.6561677554791459

# %%
# checking cv score for Decision Tree Regressor
print(cross_val_score(DTR,x,y,cv=5).mean())
# Out:
# 0.320319850131078

# %%
# checking cv score for KNN Regressor
print(cross_val_score(knn,x,y,cv=5).mean())
# Out:
# 0.5207331590154807

# %%
# checking cv score for Gradient Boosting Regressor
print(cross_val_score(GB,x,y,cv=5).mean())
# Out:
# 0.6604563881779624

# %%
from sklearn.model_selection import GridSearchCV

# Random Forest Regressor
parameters = {'criterion':['mse','mae'],
             'max_features':['auto','sqrt','log2'],
             'n_estimators':[0,200],
             'max_depth':[2,3,4,6]}

# %%
GCV = GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': [2, 3, 4, 6],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [0, 200]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 6,
#  'max_features': 'sqrt',
#  'n_estimators': 200}

# %%
capacity = RandomForestRegressor(criterion='mse',max_depth=6, max_features='log2', n_estimators=200)
capacity.fit(x_train,y_train)
pred = capacity.predict(x_test)
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test,predRFR)))
print('R2_Score:',r2_score(y_test,pred)*100)
# Out:
# RMSE value: 86.38333090197617
# R2_Score: 79.01246498613695

# %% [markdown]
# Here we saw that after Tuning the R2_Score has been increased from 65 to 79 that is good.

# %%
import joblib
joblib.dump(capacity,"Global_Power_Plant.pkl")
# Out:
# ['Global_Power_Plant.pkl']
