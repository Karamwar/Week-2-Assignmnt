# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sn

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("census_income.csv")

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.head(10)
# Out:
#    Age          Workclass  Fnlwgt      Education  Education_num  \
# 0   50   Self-emp-not-inc   83311      Bachelors             13
# 1   38            Private  215646        HS-grad              9
# 2   53            Private  234721           11th              7
# 3   28            Private  338409      Bachelors             13
# 4   37            Private  284582        Masters             14
# 5   49            Private  160187            9th              5
# 6   52   Self-emp-not-inc  209642        HS-grad              9
# 7   31            Private   45781        Masters             14
# 8   42            Private  159449      Bachelors             13
# 9   37            Private  280464   Some-college             10
#
#            Marital_status          Occupation    Relationship    Race  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
df.tail(10)
# Out:
#        Age      Workclass  Fnlwgt      Education  Education_num  \
# 32550   32        Private   34066           10th              6
# 32551   43        Private   84661      Assoc-voc             11
# 32552   32        Private  116138        Masters             14
# 32553   53        Private  321865        Masters             14
# 32554   22        Private  310152   Some-college             10
# 32555   27        Private  257302     Assoc-acdm             12
# 32556   40        Private  154374        HS-grad              9
# 32557   58        Private  151910        HS-grad              9
# 32558   22        Private  201490        HS-grad              9
# 32559   52   Self-emp-inc  287927        HS-grad              9
#
#             Marital_status          Occupation    Relationship  \
# 32550   Married-civ-spouse   Handlers-cleaners         Husband
# 32551   Married-civ-spouse               Sales         Husband
# 32552        Never-married        Tech-support   Not-in-family
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df.isnull()
# Out:
#          Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0      False      False   False      False          False           False
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 32555  False      False   False      False          False           False
# 32556  False      False   False      False          False           False
# 32557  False      False   False      False          False           False
# 32558  False      False   False      False          False           False
# 32559  False      False   False      False          False           False
#
#        Occupation  Relationship   Race    Sex  Capital_gain  Capital_loss  \
# ...

# %%
sn.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# percentage of data missing from each column of the dataframe
df.isnull().mean()
# Out:
# Age               0.0
# Workclass         0.0
# Fnlwgt            0.0
# Education         0.0
# Education_num     0.0
# Marital_status    0.0
# Occupation        0.0
# Relationship      0.0
# Race              0.0
# Sex               0.0
# Capital_gain      0.0
# Capital_loss      0.0
# Hours_per_week    0.0
# Native_country    0.0
# Income            0.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
sns.pairplot(df,diag_kind="kde")

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Fnlwgt'}>],
#        [<AxesSubplot:title={'center':'Education_num'}>,
#         <AxesSubplot:title={'center':'Capital_gain'}>],
#        [<AxesSubplot:title={'center':'Capital_loss'}>,
#         <AxesSubplot:title={'center':'Hours_per_week'}>]], dtype=object)

# %%
print(df['Income'].value_counts())
df['Income'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64
# <AxesSubplot:ylabel='Income'>

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 25, 15
df[['Age','Workclass', 'Fnlwgt','Education','Education_num','Marital_status','Occupation','Relationship','Race','Sex','Capital_gain', 'Capital_loss', 'Hours_per_week',]].hist()
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Fnlwgt'}>],
#        [<AxesSubplot:title={'center':'Education_num'}>,
#         <AxesSubplot:title={'center':'Capital_gain'}>],
#        [<AxesSubplot:title={'center':'Capital_loss'}>,
#         <AxesSubplot:title={'center':'Hours_per_week'}>]], dtype=object)

# %%
df['Workclass'].hist(grid=True)
plt.title('')
plt.show()

# %%
df['Education'].hist(grid=True)
plt.title('')
plt.show()

# %%
df['Marital_status'].hist(grid=True)
plt.title('')
plt.show()

# %%
df['Occupation'].hist(grid=True)
plt.title('')
plt.show()

# %%
df['Relationship'].hist(grid=True)
plt.title('')
plt.show()

# %%
df['Race'].hist(grid=True)
plt.title('')
plt.show()

# %%
plt.figure(figsize=(15,10))
sn.countplot(df.Sex)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(20,15))
sn.countplot(df.Native_country)
# Out:
# <AxesSubplot:xlabel='Native_country', ylabel='count'>

# %%
plt.figure(figsize=(20,15))
sn.countplot(df.Hours_per_week)
# Out:
# <AxesSubplot:xlabel='Hours_per_week', ylabel='count'>

# %%
sn.set(style="whitegrid")
ax = sn.boxplot(x=df["Age"])

# %%
sn.distplot(df['Age'], hist=True, kde=True, 
             bins=int(140/5), color = 'red', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 10})
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
df_rel = df[['Workclass','Fnlwgt','Age']]
df_rel.head()
# Out:
#            Workclass  Fnlwgt  Age
# 0   Self-emp-not-inc   83311   50
# 1            Private  215646   38
# 2            Private  234721   53
# 3            Private  338409   28
# 4            Private  284582   37

# %%
sn.pairplot(df_rel, hue='Workclass')

# %%
sn.pairplot(df_rel, hue='Fnlwgt')

# %%
sn.pairplot(df_rel, hue='Age')

# %%
sn.barplot(df.Sex,df['Hours_per_week'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Hours_per_week'>

# %%
plt.figure(figsize=(15,10))
sn.countplot(df['Age'],hue=df.Income)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.xticks(rotation = 90)
sn.countplot(x = 'Occupation', hue = 'Income', data = df)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
sn.countplot(x = 'Race', hue = 'Income', data = df)
# Out:
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %%
sn.countplot(x = 'Sex', hue = 'Income', data = df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sn.countplot(df['Marital_status'],hue=df.Income)
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sn.countplot(df['Education'],hue=df.Income)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sn.countplot(df['Race'],hue=df.Income)
# Out:
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %%
df.groupby(["Race","Sex"]).size().unstack("Sex").plot(kind="bar",fontsize=10,figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Race'>

# %%
dfcorr=df.corr()
dfcorr
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
#
#                 Hours_per_week
# Age                   0.068756
# Fnlwgt               -0.018770
# Education_num         0.148127
# Capital_gain          0.078409
# Capital_loss          0.054256
# Hours_per_week        1.000000

# %%
import matplotlib.pyplot as plt
#correlation matrix
plt.figure(figsize=(20,15))
#ax=subplot(111)
matrix = np.triu(df.corr())
sns.heatmap(df.corr(), annot=True, mask=matrix)
# Out:
# <AxesSubplot:>

# %%
labelencoder = preprocessing.LabelEncoder()
df['Workclass'] = labelencoder.fit_transform(df.Workclass)
df['Marital_status'] = labelencoder.fit_transform(df.Marital_status)
df['Occupation'] = labelencoder.fit_transform(df.Occupation)
df['Relationship'] = labelencoder.fit_transform(df.Relationship)
df['Race'] = labelencoder.fit_transform(df.Race)
df['Sex'] = labelencoder.fit_transform(df.Sex)
df['Education'] = labelencoder.fit_transform(df.Education)
df['Education_num'] = labelencoder.fit_transform(df.Education_num)
df['Native_country'] = labelencoder.fit_transform(df.Native_country)
df['Income'] = labelencoder.fit_transform(df.Income)
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             12               2
# 1       38          4  215646         11              8               0
# 2       53          4  234721          1              6               2
# 3       28          4  338409          9             12               2
# 4       37          4  284582         12             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             11               2
# 32556   40          4  154374         11              8               2
# 32557   58          4  151910         11              8               6
# 32558   22          4  201490         11              8               4
# 32559   52          5  287927         11              8               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
plt.figure(figsize=(100,200))
df.plot(kind="box", subplots=True, layout=(2,9))
# Out:
# Age                  AxesSubplot(0.125,0.536818;0.0731132x0.343182)
# Workclass         AxesSubplot(0.212736,0.536818;0.0731132x0.343182)
# Fnlwgt            AxesSubplot(0.300472,0.536818;0.0731132x0.343182)
# Education         AxesSubplot(0.388208,0.536818;0.0731132x0.343182)
# Education_num     AxesSubplot(0.475943,0.536818;0.0731132x0.343182)
# Marital_status    AxesSubplot(0.563679,0.536818;0.0731132x0.343182)
# Occupation        AxesSubplot(0.651415,0.536818;0.0731132x0.343182)
# Relationship      AxesSubplot(0.739151,0.536818;0.0731132x0.343182)
# Race              AxesSubplot(0.826887,0.536818;0.0731132x0.343182)
# Sex                     AxesSubplot(0.125,0.125;0.0731132x0.343182)
# Capital_gain         AxesSubplot(0.212736,0.125;0.0731132x0.343182)
# Capital_loss         AxesSubplot(0.300472,0.125;0.0731132x0.343182)
# Hours_per_week       AxesSubplot(0.388208,0.125;0.0731132x0.343182)
# Native_country       AxesSubplot(0.475943,0.125;0.0731132x0.343182)
# ...

# %%
out=["Age","Fnlwgt","Education_num","Capital_gain","Capital_loss","Hours_per_week"]
for i in out:
    sn.boxplot(df[i])
    plt.show()

# %%
df
# Out:
#             Age  Workclass     Fnlwgt  Education  Education_num  \
# 0      3.931826          6  11.330348          9             12
# 1      3.663562          4  12.281398         11              8
# 2      3.988984          4  12.366157          1              6
# 3      3.367296          4  12.732013          9             12
# 4      3.637586          4  12.558780         12             13
# ...         ...        ...        ...        ...            ...
# 32555  3.332205          4  12.458010          7             11
# 32556  3.713572          4  11.947140         11              8
# 32557  4.077537          4  11.931050         11              8
# 32558  3.135494          4  12.213500         11              8
# 32559  3.970292          5  12.570466         11              8
#
#        Marital_status  Occupation  Relationship  Race  Sex  Capital_gain  \
# 0                   2           4      0.000000     4    1      0.000000
# ...

# %%
df.dtypes
# Out:
# Age               float64
# Workclass           int32
# Fnlwgt            float64
# Education           int32
# Education_num       int64
# Marital_status      int32
# Occupation          int32
# Relationship      float64
# Race                int32
# Sex                 int32
# Capital_gain      float64
# Capital_loss      float64
# Hours_per_week      int64
# Native_country      int32
# Income            float64
# dtype: object

# %%
# z score technique
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (32560, 15)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    3,     9,    10, ..., 32532, 32550, 32552], dtype=int64), array([13, 12,  8, ...,  8,  8,  8], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (32560, 15)
# (27417, 15)

# %%
loss_percent=((32560-28094)/32560)*100
loss_percent
# Out:
# 13.716216216216214

# %%
# splitting x and y
x=df.drop("Income",axis=1)
y=df["Income"]

# %%
x.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             12               2
# 1   38          4  215646         11              8               0
# 2   53          4  234721          1              6               2
# 3   28          4  338409          9             12               2
# 4   37          4  284582         12             13               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
# 2           6             0     2    1             0             0
# 3          10             5     2    0             0             0
# 4           4             5     4    0             0             0
#
#    Hours_per_week  Native_country
# 0              13              39
# 1              40              39
# 2              40              39
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Income, dtype: int32

# %%
x_train, x_test, y_train, y_test=train_test_split( x, y, test_size=0.33,random_state=15)

# %%
x_train.shape
# Out:
# (21815, 14)

# %%
x_test.shape
# Out:
# (10745, 14)

# %%
y_train.shape
# Out:
# (21815,)

# %%
y_test.shape
# Out:
# (10745,)

# %% [markdown]
# # Modelling

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import BaggingClassifier

# %% [markdown]
# # Bagging classifier

# %%
model = BaggingClassifier(n_estimators=50)
model.fit(x_train,y_train)
# Out:
# BaggingClassifier(n_estimators=50)

# %%
BaggingClassifier(base_estimator=None, bootstrap=True, bootstrap_features=False,
                  max_features=1.0, max_samples=1.0, n_estimators=50,
                  n_jobs=None, oob_score=False, random_state=None, verbose=0,
                  warm_start=False)
# Out:
# BaggingClassifier(n_estimators=50)

# %%
y_pred=model.predict(x_test)
acc_score=metrics.accuracy_score(y_test,y_pred)
print("Accuracy of Test:", acc_score)
# Out:
# Accuracy of Test: 0.8571428571428571

# %%
y_pred = model.predict(x_train)

# %%
acc_score = metrics.accuracy_score(y_train,y_pred)
print(acc_score)
# Out:
# 0.999633279853312

# %%
df.skew()
# Out:
# Age                0.558738
# Workclass         -0.752280
# Fnlwgt             1.446972
# Education         -0.934063
# Education_num     -0.311630
# Marital_status    -0.013448
# Occupation         0.114540
# Relationship       0.786784
# Race              -2.435332
# Sex               -0.719244
# Capital_gain      11.953690
# Capital_loss       4.594549
# Hours_per_week     0.227636
# Native_country    -3.658235
# Income             1.212383
# dtype: float64

# %%
for col in df:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# Age              -0.113322
# Workclass        -0.752280
# Fnlwgt           -0.842559
# Education        -0.934063
# Education_num    -0.311630
# Marital_status   -0.013448
# Occupation        0.114540
# Relationship      0.284979
# Race             -2.435332
# Sex              -0.719244
# Capital_gain      3.096803
# Capital_loss      4.307460
# Hours_per_week    0.227636
# Native_country   -3.658235
# Income            1.212383
# dtype: float64

# %% [markdown]
# # Logistic Regression model

# %%
log = LogisticRegression()
log.fit(x_train,y_train)
predlog = log.predict(x_test)
print(accuracy_score(y_test, predlog))
print(confusion_matrix(y_test, predlog))
print(classification_report(y_test,predlog))
# Out:
# 0.7907599157599158
# [[16446   871]
#  [ 3898  1577]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.87     17317
#            1       0.64      0.29      0.40      5475
#
#     accuracy                           0.79     22792
#    macro avg       0.73      0.62      0.64     22792
# weighted avg       0.77      0.79      0.76     22792

# %%
# Lets plot confusion matrix for DTC
cm = confusion_matrix(y_test,predlog)

x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
preddt = dt.predict(x_test)
print(accuracy_score(y_test, preddt))
print(confusion_matrix(y_test, preddt))
print(classification_report(y_test,preddt))
# Out:
# 0.8085293085293085
# [[15112  2205]
#  [ 2159  3316]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87     17317
#            1       0.60      0.61      0.60      5475
#
#     accuracy                           0.81     22792
#    macro avg       0.74      0.74      0.74     22792
# weighted avg       0.81      0.81      0.81     22792

# %%
# Lets plot confusion matrix for DTC
cm = confusion_matrix(y_test,preddt)

x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Decision Tree Classifier')
plt.show()

# %% [markdown]
# # SVC Model

# %%
sv=SVC()
sv.fit(x_train,y_train)
pred_sv=sv.predict(x_test)
print("R2 score: ", accuracy_score(y_test,pred_sv))
print("Confusion Matrix: ",confusion_matrix(y_test,pred_sv))
print(classification_report(y_test,pred_sv))
# Out:
# R2 score:  0.7803176553176553
# Confusion Matrix:  [[17306    11]
#  [ 4996   479]]
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.87     17317
#            1       0.98      0.09      0.16      5475
#
#     accuracy                           0.78     22792
#    macro avg       0.88      0.54      0.52     22792
# weighted avg       0.82      0.78      0.70     22792

# %%
cm=confusion_matrix(y_test, pred_sv)

x_axis_labels= ["<=50",">50"]
y_axis_labels= ["<=50",">50"]

f, ax = plt.subplots(figsize=(9,9))
sns.heatmap(cm,annot=True, fmt=".0f", linecolor="black")
plt.xlabel("predicted")
plt.ylabel("True")
plt.title("Confusion Matrix for SVC")
plt.show()

# %% [markdown]
# # KNN Classifiers

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN

knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
print("R2 Score: ", accuracy_score(y_test,pred_knn))
print("Confusion Matrix: ", confusion_matrix(y_test,pred_knn))
print(classification_report(y_test,pred_knn))
# Out:
# R2 Score:  0.7716303966303967
# Confusion Matrix:  [[16062  1255]
#  [ 3950  1525]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86     17317
#            1       0.55      0.28      0.37      5475
#
#     accuracy                           0.77     22792
#    macro avg       0.68      0.60      0.62     22792
# weighted avg       0.74      0.77      0.74     22792

# %%
cm=confusion_matrix(y_test, pred_knn)

x_axis_labels= ["<=50",">50"]
y_axis_labels= ["<=50",">50"]

f, ax = plt.subplots(figsize=(9,9))
sns.heatmap(cm,annot=True, fmt=".0f", linecolor="black")
plt.xlabel("predicted")
plt.ylabel("True")
plt.title("Confusion Matrix for KNN")
plt.show()

# %% [markdown]
# # Random Forest Classifier

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train, y_train)
predrfc=rfc.predict(x_test)
print(accuracy_score(y_test, predrfc))
print(confusion_matrix(y_test, predrfc))
print(classification_report(y_test,predrfc))
# Out:
# 0.8511758511758512
# [[16181  1136]
#  [ 2256  3219]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91     17317
#            1       0.74      0.59      0.65      5475
#
#     accuracy                           0.85     22792
#    macro avg       0.81      0.76      0.78     22792
# weighted avg       0.84      0.85      0.85     22792

# %%
cm=confusion_matrix(y_test, predrfc)

x_axis_labels= ["<=50",">50"]
y_axis_labels= ["<=50",">50"]

f, ax = plt.subplots(figsize=(9,9))
sns.heatmap(cm,annot=True, fmt=".0f", linecolor="black")
plt.xlabel("predicted")
plt.ylabel("True")
plt.title("Confusion Matrix for RFC")
plt.show()

# %% [markdown]
# # Gradient  Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier, BaggingClassifier

gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
pred_gbc=gbc.predict(x_test)
print("R2 score: ", accuracy_score(y_test,pred_gbc))
print("Confusion Matrix: ",confusion_matrix(y_test,pred_gbc))
print(classification_report(y_test,pred_gbc))
# Out:
# R2 score:  0.8617936117936118
# Confusion Matrix:  [[16522   795]
#  [ 2355  3120]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91     17317
#            1       0.80      0.57      0.66      5475
#
#     accuracy                           0.86     22792
#    macro avg       0.84      0.76      0.79     22792
# weighted avg       0.86      0.86      0.85     22792

# %%
# Lets plot confusion matrix for  GBClassifier
cm = confusion_matrix(y_test,pred_gbc)

x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for  XGBClassifier')
plt.show()

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
# cv score for log
print(cross_val_score(log,x,y,cv=5).mean())
# Out:
# 0.7922297297297297

# %%
# cv score for dtc
print(cross_val_score(dtc,x,y,cv=5).mean())
# Out:
# 0.8075552825552826

# %%
# cv score for knn
print(cross_val_score(knn,x,y,cv=5).mean())
# Out:
# 0.7765663390663391

# %%
# cv score for Rfc
print(cross_val_score(rfc,x,y,cv=5).mean())
# Out:
# 0.8562039312039312

# %%
# cv score of GBC
print(cross_val_score(gbc,x,y,cv=5).mean())
# Out:
# 0.8640356265356266

# %% [markdown]
# # ROC-AUC Curve

# %%
# importing required libraries
from sklearn import datasets
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import plot_roc_curve
dis=plot_roc_curve(rfc,x_test,y_test)
plot_roc_curve(knn,x_test,y_test, ax=dis.ax_)
plot_roc_curve(sv,x_test,y_test, ax=dis.ax_)
plot_roc_curve(gbc,x_test,y_test, ax=dis.ax_)
plot_roc_curve(log,x_test,y_test, ax=dis.ax_)
plot_roc_curve(dt,x_test,y_test, ax=dis.ax_)
plot_roc_curve(rfc,x_test,y_test, ax=dis.ax_)

plt.legend(prop={"size":9}, loc="lower right")
plt.show()

# %% [markdown]
# # Here we see that the Gradient Boosting Classifier has Max Accuracy with 0.92

# %% [markdown]
# # Saving Model:

# %%
# importing required library
import joblib
joblib.dump(gbc,'census_income_project.obj')
# Out:
# ['census_income_project.obj']

# %% [markdown]
# # Model and Predictions loading

# %%
# loading the saved model
model=joblib.load("census_income_project.obj")

prediction=model.predict(x_test)
prediction
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["predicted","Actual"])
# Out:
#            0      1      2      3      4      5      6      7      8      \
# predicted      0      0      0      1      1      0      0      0      0
# Actual         0      0      0      1      1      0      1      0      0
#
#            9      ...  22782  22783  22784  22785  22786  22787  22788  22789  \
# predicted      1  ...      1      0      0      0      0      0      0      0
# Actual         1  ...      0      0      0      0      0      0      0      0
#
#            22790  22791
# predicted      0      0
# Actual         0      0
#
# [2 rows x 22792 columns]
